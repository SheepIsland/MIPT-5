# %% [markdown]
# # 2 Requests / urllib + beautifulSoap

# %% [markdown]
# ***
# 1. Скачайте html код страницы с новостью любого новостного сайта и, распарсив его с помощью библиотеки Beautiful Soup или любой другой аналогичной, получите текст статьи (без html тегов или вкравплений js).
# ***

# %%
import urllib
import re
from bs4 import BeautifulSoup
 
def innecessaryTags(element):
    if element.parent.name in ['head','style', 'script', 'title','[document]']:
        return False
    return True    

html = urllib.request.urlopen('https://edition.cnn.com/2018/12/08/politics/donald-trump-robert-mueller-john-kelly-russia-emmanuel-macron/index.html')
beautifulSoup = BeautifulSoup(html, "lxml")
text = soup.findAll(text=True)
result = list(filter(innecessaryTags, text))
 
for i in result:
    print (i)
# Out:
# Breaking News
# 45
# Congress
# Supreme Court
# 2018 Election Results
# Search »
# Trump tries to change the story, but Russia cloud darkens
# Analysis by
# Stephen Collinson
# , CNN
# Updated 0223 GMT (1023 HKT) December 9, 2018
# Chat with us in Facebook Messenger. Find out what's happening in the world as it unfolds.
# JUST WATCHED
# Mueller to drop Cohen, Manafort memos
# Replay
# More Videos ...
# MUST WATCH
#  (16 Videos)
# Mueller to drop Cohen, Manafort memos
# House GOP releases Comey interview transcript
# Undocumented staff claim Trump club hired them
# NYT: Kushner offered Saudi Crown Prince advice
# Trump: John Kelly leaving at end of the year
# Trump nominates new Joint Chiefs chairman
# Conway's husband trolls Trump's tweet
# Burnett: Mueller drops a major bomb on Trump
# Mueller: Manafort lied about major issues
# Trump: Some GOP candidates 'choke like dogs'
# Trump on filing: Totally clears the President
# Prosecutors, Special Counsel release filings for Cohen
# ...
